# %%
# @hidden_cell
# The project token is an authorization token that is used to access project resources like data sources, connections, and used by platform APIs.
from project_lib import Project
project = Project(project_id='<ProjectID>', project_access_token='<ProjectAccessToken>')
pc = project.project_context

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np

# %%
# Downloading the package for collecting weather from world weather online api
# !pip install wwo-hist
# Out:
# Collecting wwo-hist
#   Downloading https://files.pythonhosted.org/packages/5a/b4/19a4d6a0d131567cf4b2ffa3758710d867f7d7d3f0c6f94bd63fadf1d02a/wwo_hist-0.0.5-py3-none-any.whl
# Installing collected packages: wwo-hist
# Successfully installed wwo-hist-0.0.5

# %%
# libraries for date time conversion into required format
from datetime import datetime, date, timedelta
import time

# %%
# importing dataset from
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_bed3c3c1607144b69077066929a4f961 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='APIkey',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_bed3c3c1607144b69077066929a4f961.get_object(Bucket='ibmhackchallenge2020-donotdelete-pr-n0hs7jsuxlpv6c',Key='T1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#           Date/Time  LV ActivePower (kW)  Wind Speed (m/s)  \
# 0  01 01 2018 00:00           380.047791          5.311336
# 1  01 01 2018 00:10           453.769196          5.672167
# 2  01 01 2018 00:20           306.376587          5.216037
# 3  01 01 2018 00:30           419.645905          5.659674
# 4  01 01 2018 00:40           380.650696          5.577941
#
#    Theoretical_Power_Curve (KWh)  Wind Direction (°)
# 0                     416.328908          259.994904
# 1                     519.917511          268.641113
# 2                     390.900016          272.564789
# 3                     516.127569          271.258087
# 4                     491.702972          265.674286

# %%
# checking the shape of dataset
df.shape
# Out:
# (50530, 5)

# %%
# keys of the weather API
world_weather_keys = ["151d22887cd746c8b30170119200305","a2a4c031e1174540953170617200305","3b8d0ddf95874ebc963171315200305","a7a8a673626349d6b2b171426200305",
                      "2c7acfdf3cd94dd6980171732200305","f2d087202dd74d3b8e9171937200305","dc721b5c73524d18bdc171944200305","a26775efe1e249b0a07172328200305",
                      "08ba377d157442f7b02172339200305","b32f31b4b4434128b88172618200305","54c5c4326ada4f189fc172631200305","c6f169f91683422f8ba172832200305",
                      "a39f242f81784b21808173201200305","e16a33c0b36040069aa173413200305","a39f242f81784b21808173201200305","01efbb6048bb48cc894173827200305",
                      "539ecc5092544eb087f173940200305","3d1b0704663e46e18f4174348200305","a339dad955e74b37a53174426200305","e2d4e57fb25f4535abf174810200305",
                      "e2fca3c1ea1a41c395f174907200305","f381fc760b034b70805175107200305","87ceb9281638401ca07175304200305","2c5dab9b79eb4daa9fb175507200305",
                      "e486c0fcdba54022b52150217200505","73160037869d421c95f150902200505","9c61f783fcd9467fb8e151028200505","25ac72b90a114c04963151054200505",
                      "40b9b6abd1ee4f3bab6151141200505","871cfe6fa20f440399f151257200505","36b3fc4cd1bc41aa9d7155722200505",
                      "f07f174181434b5e9e3155957200505","f280bed306334e0f9a2160217200505",
                      "6d401b23e9164970bc9160321200505","32309a1471524556b73160532200505","6af18246b3c748488f0160649200505",
                      "bd0cc1e7a4c14783bb1160745200505","65b031b57a9c41b5825161035200505","03ed5a8e69f5440087a161038200505","b17a228605634f84b51161207200505",
                      "f0b2df13be40426da7e161307200505","74b95c5a3847420d860161401200505","221fcd82d40f412fa77161510200505","d904fcc09e794699933161642200505",
                      "ca5283987239404aa31161717200505","cb7c0e83d493492081e161810200505","3b66bdc3b2ea4d2dabb161835200505","16f6c54894074e1bbdd162020200505",
                      "b6c7e4787cab459e801162135200505","a0d9bc141f2048dba26162253200505","fa5e3c18fbee4effbc0162451200505","4ee182c9c70842a088c162813200505",
                      "acc60e0fdbab42daa83134613202004","5eb463dfdc5d436ba88134816202004","34def415e62e44de976135004202004",
                      "07d2ac83254044fc92a135155202004","455d1b95e8474272964135343202004","f939c3f727eb46478a0135529202004",
                      "4b6a700637554250bad140000202004","760d2952fdb2440b9b6140246202004","febfd6293d25460591c75731202104",
                      "7361ac700d7c40ebb2675910202104","d384d3c0b88842b088483502202104","a72ea582edff4fb9a9d90545202104",
                      "954356550d2d4e31ab990731202104","12402144412b44a3bb290848202104","3494faf7c7304393bf391011202104"
                     ]

# %%
len(world_weather_keys)
# Out:
# 142

# %%
# importing function for retriving historical data 
from wwo_hist import retrieve_hist_data

# %%
# frequency means no_of_hours  
frequency=1

final_data_new = []
# count to keep track of no_of_records collected
count = 0

# current_key_count to check the no_of_calls of current_key
current_key_count = 0

# key_track to keep track of key
key_track = 0
current_key = world_weather_keys[key_track]

# max number of requests from single key in one day
max_key_count = 500

# requests_time_out to keep track of number of times the request timed out 
requests_time_out = 0

# The latitude and longitude of wind farm of dataset in turkey, yalova
lat_long = ["40.6549,29.2842"]
for i in df.values:
    end_date = datetime.strptime(i[0], '%d %m %Y %H:%M')
    start_date = end_date
    one_row = []

    if current_key_count > max_key_count:
        key_track += 1
        current_key = world_weather_keys[key_track]
        current_key_count = 0
    try:
        hist_weather_data = retrieve_hist_data(current_key,
                                  lat_long,
                                  start_date,
                                  end_date,
                                  frequency,
                                  location_label = False,
                                  export_csv = False,
                                  store_df = True
                                  )
        current_key_count += 1
        
        records = hist_weather_data[0]
#         converting columns to numeric type 
        records = records[["maxtempC", "WindGustKmph", "DewPointC", "WindChillC", "humidity", "precipMM", "pressure"]].apply(pd.to_numeric)
        
        maxtempC = records["maxtempC"].values
        windGustKmph = records["WindGustKmph"].values
        DewPointC = records["DewPointC"].values
        windChillC = records["WindChillC"].values
        humidity = records["humidity"].values
        precipMM = records["precipMM"].values
        pressure = records["pressure"].values         
        
#         taking the average of every weather feature as data coming is from one hour before the date_time requested
        one_row.append([ end_date,  sum(maxtempC) / len(maxtempC), sum(windGustKmph) / len(windGustKmph), 
                         sum(DewPointC) / len(DewPointC), sum(windChillC) / len(windChillC),
                         sum(humidity) / len(humidity), sum(precipMM) / len(precipMM), sum(pressure) / len(pressure)])

    except HTTPError:
        requests_time_out += 1

    final_data_new.extend(one_row)  

    count += 1

    if count % 1000 == 0:
        print("Count:{}, Len(Final data):{}, key track:{}".format(count, len(final_data_new), key_track))
# Out:
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-26 to 2018-10-26
# Time elapsed (hh:mm:ss.ms) 0:00:00.368257
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-26 to 2018-10-26
# Time elapsed (hh:mm:ss.ms) 0:00:00.434515
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.395113
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.365210
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.221120
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.103969
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.119881
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.110727
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.105946
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.156435
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.110782
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.106081
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.426691
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.108383
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.107907
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.105891
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.136126
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.135329
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.137588
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.102450
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.142634
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.110975
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.123505
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00.109865
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-10-27 to 2018-10-27
# Time elapsed (hh:mm:ss.ms) 0:00:00
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108480
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.106408
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.119778
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.135454
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.107565
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108931
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.103996
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.104867
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.110708
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.143880
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136544
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.132989
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.138693
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136799
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.137117
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.109325
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.120737
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.107152
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.140708
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.110565
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.104662
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.111352
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.159320
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.129432
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.134170
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.135777
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.130318
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.129961
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.103075
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.103293
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108294
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.107736
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.130842
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.132024
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.133528
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.115951
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.116914
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.199766
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.114965
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136468
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.106835
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.137225
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.098040
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.154283
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.127971
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.101599
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.110140
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.117783
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.129437
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.105568
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.107131
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.134511
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.101951
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.105548
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.109619
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.133332
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108900
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.182675
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.133932
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.135647
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.105580
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.113875
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.112569
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108476
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136833
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.099189
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.108243
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.127420
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.126861
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.109368
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.131572
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136544
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.100707
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.105529
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.100194
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.137790
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.129698
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.101987
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.175298
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.101644
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.136333
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.131194
#
#
# Retrieving weather data for 40.6549,29.2842
#
#
# Currently retrieving data for 40.6549,29.2842: from 2018-12-31 to 2018-12-31
# Time elapsed (hh:mm:ss.ms) 0:00:00.099481

# %%
len(final_data_new)
# Out:
# 50530

# %%
data_integrated = np.concatenate( (df.values, np.array(final_data_new)), axis = 1 )

# %%
df = pd.DataFrame( data_integrated, columns = ["DateTime", "LV ActivePower", "Wind Speed (m/s)", "Theoretical_Power_Curve (KWh)", "Wind Direction",
                                         "end_date",  "maxtempC", "windGustKmph", "DewPointC", "windChillC", "humidity", "precipMM", "pressure"] )

# %%
df.drop(df.columns[0], axis=1, inplace = True)

# %%
df["end_date"] = df["end_date"].apply(pd.to_datetime)

# %%
lVActivePower = df["LV ActivePower"]
df.drop("LV ActivePower", axis = 1, inplace = True)

# %%
df["LV ActivePower"] = lVActivePower
df.head()
# Out:
#   Wind Speed (m/s) Theoretical_Power_Curve (KWh) Wind Direction  \
# 0          5.31134                       416.329        259.995
# 1          5.67217                       519.918        268.641
# 2          5.21604                         390.9        272.565
# 3          5.65967                       516.128        271.258
# 4          5.57794                       491.703        265.674
#
#              end_date maxtempC windGustKmph DewPointC windChillC humidity  \
# 0 2018-01-01 00:00:00       10       11.125   2.20833    6.33333  69.9167
# 1 2018-01-01 00:10:00       10       11.125   2.20833    6.33333  69.9167
# 2 2018-01-01 00:20:00       10       11.125   2.20833    6.33333  69.9167
# 3 2018-01-01 00:30:00       10       11.125   2.20833    6.33333  69.9167
# 4 2018-01-01 00:40:00       10       11.125   2.20833    6.33333  69.9167
#
#   precipMM pressure LV ActivePower
# 0        0  1017.62        380.048
# 1        0  1017.62        453.769
# 2        0  1017.62        306.377
# 3        0  1017.62        419.646
# 4        0  1017.62        380.651

# %%
from project_lib import Project
project = Project(pc,'<ProjectID>','<ProjectAccessToken>')

project.save_data(file_name = "integrated_data.csv",data = df.to_csv(index=False))
# Out:
# {'file_name': 'integrated_data.csv',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'ibmhackchallenge2020-donotdelete-pr-n0hs7jsuxlpv6c',
#  'asset_id': '311eeb17-4c6b-4606-a5a7-bc26e5f17344'}
